# %%
import os
import re
import pandas as pd
import numpy as np
import pickle
import joblib
from sqlalchemy import create_engine
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, make_scorer, classification_report
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import xgboost as xgb

nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
# Out:
# [nltk_data] Remote end closed connection without response
# False

# %%
conn = create_engine('sqlite:///data/disaster_response.db')
df = pd.read_sql_table('df', conn)

# %%
# pd.read_sql_query('SELECT * FROM df;', conn)

# %%
df.head(1)

# %%
# X = df['message'][:5]
# y = df.drop(['id', 'message', 'original', 'genre_news', 'genre_social', 'genre'], axis = 1).iloc[:5,]

# %%
X = df['message']
y = df.drop(['id', 'message', 'original', 'genre_news', 'genre_social', 'genre'], axis = 1)

# %%
url_regex = 'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'

def tokenize(text):
    detected_urls = re.findall(url_regex, text)
    for url in detected_urls:
        text = text.replace(url, 'url_placeholder')
        
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
        
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()
    
    stopwords_ = stopwords.words("english")
    words = [word for word in tokens if word not in stopwords_]
    
    clean_tokens = []
    for token in tokens:
        clean_token = lemmatizer.lemmatize(token).lower().strip()
        clean_tokens.append(clean_token)
        
    return clean_tokens

def build_model_pipeline():
    pipeline = Pipeline([
        ('features', FeatureUnion([
                    ('text_pipeline', Pipeline([
                                ('vect', CountVectorizer(tokenizer=tokenize)),
                                ('tfidf', TfidfTransformer())
                            ])),
                    ('starting_verb', StartingVerbExtractor())
                        ])),
        ('clf', MultiOutputClassifier(xgb.XGBClassifier()))
                    ])
    return pipeline

class StartingVerbExtractor(BaseEstimator, TransformerMixin):
    
    def starting_verb(self, text):
        sentence_list = nltk.sent_tokenize(text)
        
        for sentence in sentence_list:
            pos_tags = nltk.pos_tag(tokenize(sentence))
            
            try:
                first_word, first_tag = pos_tags[0]
            except IndexError:
                pass
            else:
                if first_tag in ['VB', 'VBP']:
                    return True
        return False
    
    def fit(self, x, y=None):
        return self
    
    def transform(self, X):
        X_tagged = pd.Series(X).apply(self.starting_verb)
        return pd.DataFrame(X_tagged)
            

def eval_metrics(actual, predicted, column_names):
    """
    calculate evaluation metrics for model
    
    INPUT: 
    --actual : array of actual labels
    --predicted: array of predicted labels
    
    OUTPUT:
    --- Pandas Dataframe containing the accuracy, precision, recall 
        and f1 score for a given set of actual and predicted labels.
    """
    metrics = {'accuracy':[], 'precision':[], 'recall':[], 'f1':[]}
    for i in range(len(column_names)):
        accuracy = accuracy_score(actual.iloc[:,i], predicted[:,i])
        precision = precision_score(actual.iloc[:,i], predicted[:,i], average='weighted')
        recall = recall_score(actual.iloc[:,i], predicted[:,i], average='weighted')
        f1 = f1_score(actual.iloc[:,i], predicted[:,i], average='weighted', )
        
        metrics['accuracy'].append(accuracy)
        metrics['precision'].append(precision)
        metrics['recall'].append(recall)
        metrics['f1'].append(f1)
        print(classification_report(actual.iloc[:,i], predicted[:,i]))
        
    df = pd.DataFrame(metrics, index=column_names)
    return df

def gridsCV_scorer(actual, predicted):
    """
    calculate median median f1 score for all output classifiers
    INPUT: 
    --actual : array of actual labels
    --predicted: array of predicted labels
    
    OUTPUT: Median Output Score
    """
    f1 = []
    for i in range(actual.shape[1]):
        f1_scr = f1_score(actual.iloc[:,i], predicted[:,i], average='weighted')
        f1.append(f1_scr)
        return np.median(f1)

# %%
# %%time
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=19)
pipeline = build_model_pipeline()
pipeline.fit(X_train, y_train)
# Out:
# [('unicef', 'JJ'), ('ha', 'NN'), ('offered', 'VBD'), ('20', 'CD'), ('squatting', 'VBG'), ('pan', 'NN'), ('to', 'TO'), ('the', 'DT'), ('mosque', 'NN'), ('and', 'CC'), ('a', 'DT'), ('temporary', 'JJ'), ('building', 'NN'), ('is', 'VBZ'), ('being', 'VBG'), ('constructed', 'VBN'), ('to', 'TO'), ('supplement', 'VB'), ('the', 'DT'), ('existing', 'VBG'), ('shelter', 'NN'), ('at', 'IN'), ('the', 'DT'), ('mosque', 'NN'), ('with', 'IN'), ('four', 'CD'), ('semi', 'NN'), ('permanent', 'JJ'), ('toilet', 'NN'), ('and', 'CC'), ('a', 'DT'), ('bathing', 'NN'), ('site', 'NN')]
# [('what', 'WDT'), ('are', 'VBP'), ('the', 'DT'), ('authority', 'NN'), ('saying', 'VBG'), ('about', 'IN'), ('the', 'DT'), ('functioning', 'NN'), ('of', 'IN'), ('the', 'DT'), ('school', 'NN'), ('in', 'IN'), ('the', 'DT'), ('rest', 'NN'), ('of', 'IN'), ('the', 'DT'), ('country', 'NN')]
# [('i', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('problem', 'NN'), ('and', 'CC'), ('i', 'NN'), ('do', 'VBP'), ('not', 'RB'), ('have', 'VB'), ('any', 'DT'), ('food', 'NN'), ('to', 'TO'), ('eat', 'VB')]
# [('can', 'MD'), ('you', 'PRP'), ('please', 'VB'), ('give', 'VB'), ('out', 'RP'), ('food', 'NN'), ('in', 'IN'), ('carrefour', 'NN')]
# [('sf', 'NN'), ('bay', 'NN'), ('area', 'NN'), ('physician', 'NN'), ('or', 'CC'), ('pa', 'NN'), ('needed', 'VBN'), ('for', 'IN'), ('medical', 'JJ'), ('marijuana', 'CD'), ('evaluation', 'NN'), ('clinic', 'NN'), ('downtown', 'NN'), ('santa', 'NN'), ('cruz', 'NN'), ('url', 'JJ'), ('placeholder', 'NN'), ('job', 'NN')]
# [('ert', 'JJ'), ('glass', 'NN'), ('conducteur', 'NN'), ('car', 'NN'), ('and', 'CC'), ('truck', 'NN'), ('operator', 'NN'), ('tractor', 'NN'), ('exp', 'NN'), ('souverain', 'VBP'), ('mathieu', 'NN'), ('1', 'CD')]
# [('the', 'DT'), ('low', 'JJ'), ('lying', 'NN'), ('irawaddy', 'NN'), ('delta', 'NN'), ('suffered', 'VBD'), ('the', 'DT'), ('effect', 'NN'), ('of', 'IN'), ('a', 'DT'), ('sizable', 'JJ'), ('storm', 'NN'), ('surge', 'NN'), ('and', 'CC'), ('many', 'JJ'), ('area', 'NN'), ('remain', 'VBP'), ('underwater', 'JJ'), ('hampering', 'VBG'), ('effort', 'NN'), ('to', 'TO'), ('reach', 'VB'), ('family', 'NN'), ('in', 'IN'), ('need', 'NN')]
# [('we', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('food', 'NN'), ('make', 'VB'), ('a', 'DT'), ('way', 'NN'), ('for', 'IN'), ('u', 'JJ'), ('please', 'VB'), ('our', 'PRP$'), ('brother', 'NN')]
# [('even', 'RB'), ('now', 'RB'), ('people', 'NNS'), ('are', 'VBP'), ('unable', 'JJ'), ('to', 'TO'), ('breathe', 'VB'), ('due', 'JJ'), ('to', 'TO'), ('the', 'DT'), ('smell', 'NN'), ('of', 'IN'), ('the', 'DT'), ('dead', 'JJ')]
# [('why', 'WRB'), ('doesn', 'NN'), ('t', 'VBD'), ('the', 'DT'), ('state', 'NN'), ('put', 'VBD'), ('up', 'RP'), ('an', 'DT'), ('electronic', 'JJ'), ('document', 'NN'), ('for', 'IN'), ('the', 'DT'), ('immigration', 'NN'), ('bureau', 'NN')]
# [('he', 'PRP'), ('said', 'VBD'), ('that', 'IN'), ('effort', 'NN'), ('were', 'VBD'), ('under', 'IN'), ('way', 'NN'), ('with', 'IN'), ('several', 'JJ'), ('institution', 'NN'), ('to', 'TO'), ('obtain', 'VB'), ('more', 'RBR'), ('tent', 'JJ'), ('to', 'TO'), ('provide', 'VB'), ('provisional', 'JJ'), ('accommodation', 'NN'), ('in', 'IN'), ('resettlement', 'JJ'), ('area', 'NN'), ('while', 'IN'), ('people', 'NNS'), ('build', 'VBP'), ('their', 'PRP$'), ('new', 'JJ'), ('home', 'NN')]
# [('the', 'DT'), ('transfer', 'NN'), ('of', 'IN'), ('the', 'DT'), ('sinjembela', 'NN'), ('refugee', 'NN'), ('however', 'RB'), ('can', 'MD'), ('not', 'RB'), ('be', 'VB'), ('conducted', 'VBN'), ('by', 'IN'), ('air', 'NN'), ('for', 'IN'), ('lack', 'NN'), ('of', 'IN'), ('a', 'DT'), ('landing', 'JJ'), ('field', 'NN'), ('in', 'IN'), ('the', 'DT'), ('area', 'NN'), ('he', 'PRP'), ('said', 'VBD')]
# [('i', 'NNS'), ('need', 'VBP'), ('a', 'DT'), ('shelter', 'NN'), ('because', 'IN'), ('i', 'JJ'), ('sleep', 'VBP'), ('out', 'RP'), ('in', 'IN'), ('the', 'DT'), ('rain', 'NN')]
# [('somalia', 'NNS'), ('s', 'VBP'), ('transitional', 'JJ'), ('federal', 'JJ'), ('government', 'NN'), ('is', 'VBZ'), ('making', 'VBG'), ('preparation', 'NN'), ('to', 'TO'), ('hand', 'NN'), ('over', 'RP'), ('power', 'NN'), ('to', 'TO'), ('an', 'DT'), ('elected', 'JJ'), ('government', 'NN'), ('in', 'IN'), ('august', 'NN')]
# [('we', 'PRP'), ('are', 'VBP'), ('in', 'IN'), ('marin', 'NN'), ('we', 'PRP'), ('never', 'RB'), ('found', 'VBD'), ('anything', 'NN'), ('they', 'PRP'), ('forgot', 'VBP'), ('if', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('victim', 'JJ'), ('like', 'IN'), ('the', 'DT'), ('others', 'NNS')]
# [('resident', 'NN'), ('who', 'WP'), ('are', 'VBP'), ('registered', 'VBN'), ('receive', 'VBP'), ('a', 'DT'), ('ration', 'NN'), ('of', 'IN'), ('mealie', 'NN'), ('maize', 'VBP'), ('the', 'DT'), ('staple', 'NN'), ('here', 'RB'), ('a', 'DT'), ('well', 'RB'), ('a', 'DT'), ('lentil', 'JJ'), ('bean', 'NN'), ('and', 'CC'), ('cooking', 'NN'), ('oil', 'NN')]
# [('need', 'NN'), ('of', 'IN'), ('information', 'NN'), ('about', 'IN'), ('the', 'DT'), ('earthquake', 'NN'), ('for', 'IN'), ('this', 'DT'), ('week', 'NN')]
# [('with', 'IN'), ('support', 'NN'), ('from', 'IN'), ('unicef', 'JJ'), ('ten', 'NN'), ('dug', 'NN'), ('well', 'RB'), ('were', 'VBD'), ('improved', 'VBN'), ('and', 'CC'), ('fitted', 'VBN'), ('with', 'IN'), ('handpumps', 'NNS'), ('in', 'IN'), ('charchino', 'NN'), ('district', 'NN'), ('of', 'IN'), ('oruzgan', 'JJ'), ('province', 'NN')]
# [('can', 'MD'), ('someone', 'NN'), ('from', 'IN'), ('the', 'DT'), ('usa', 'JJ'), ('adopt', 'VB'), ('an', 'DT'), ('18', 'CD'), ('year', 'NN'), ('old', 'JJ')]
# [('unicef', 'NN'), ('is', 'VBZ'), ('supporting', 'VBG'), ('the', 'DT'), ('distribution', 'NN'), ('of', 'IN'), ('insecticide', 'NN'), ('treated', 'VBN'), ('net', 'JJ'), ('and', 'CC'), ('will', 'MD'), ('also', 'RB'), ('work', 'VB'), ('with', 'IN'), ('local', 'JJ'), ('partner', 'NN'), ('to', 'TO'), ('ensure', 'VB'), ('timely', 'RB'), ('social', 'JJ'), ('mobilization', 'NN'), ('effort', 'NN'), ('on', 'IN'), ('the', 'DT'), ('use', 'NN'), ('of', 'IN'), ('malaria', 'JJ'), ('net', 'NN'), ('at', 'IN'), ('household', 'NN'), ('and', 'CC'), ('camp', 'NN'), ('level', 'NN')]
# [('besides', 'IN'), ('reallocating', 'VBG'), ('their', 'PRP$'), ('resource', 'NN'), ('the', 'DT'), ('ngo', 'NN'), ('have', 'VBP'), ('also', 'RB'), ('been', 'VBN'), ('providing', 'VBG'), ('additional', 'JJ'), ('assistance', 'NN')]
# [('can', 'MD'), ('you', 'PRP'), ('remind', 'VB'), ('me', 'PRP'), ('of', 'IN'), ('the', 'DT'), ('government', 'NN'), ('job', 'NN'), ('site', 'NN')]
# [('i', 'NNS'), ('need', 'VBP'), ('to', 'TO'), ('apply', 'VB'), ('for', 'IN'), ('some', 'DT'), ('job', 'NN')]
# [('the', 'DT'), ('netherlands', 'NNS'), ('ha', 'VBP'), ('released', 'VBN'), ('40', 'CD'), ('million', 'CD'), ('for', 'IN'), ('emergency', 'NN'), ('aid', 'NN'), ('which', 'WDT'), ('make', 'VBP'), ('it', 'PRP'), ('a', 'DT'), ('major', 'JJ'), ('donor', 'NN'), ('within', 'IN'), ('the', 'DT'), ('eu', 'NN')]
# [('having', 'VBG'), ('a', 'DT'), ('very', 'RB'), ('productive', 'JJ'), ('day', 'NN'), ('in', 'IN'), ('nyc', 'NN'), ('not', 'RB')]
# [('thanks', 'NNS'), ('hurricanesandylike', 'VBP'), ('the', 'DT'), ('day', 'NN'), ('after', 'IN'), ('a', 'DT'), ('snowstorm', 'NN'), ('except', 'IN'), ('it', 'PRP'), ('sand', 'VBZ'), ('not', 'RB'), ('snow', 'JJ')]
# [('never', 'RB'), ('seen', 'VBN'), ('anything', 'NN'), ('like', 'IN'), ('this', 'DT')]
# [('sic', 'JJ'), ('url', 'JJ'), ('placeholder', 'NN'), ('starting', 'VBG'), ('to', 'TO'), ('come', 'VB'), ('on', 'IN'), ('in', 'IN'), ('lower', 'JJR'), ('manhattan', 'NN'), ('meaning', 'NN'), ('there', 'EX'), ('are', 'VBP'), ('no', 'RB'), ('longer', 'RB'), ('any', 'DT'), ('remaining', 'VBG'), ('problem', 'NN'), ('because', 'IN'), ('of', 'IN'), ('sandy', 'NN')]
# [('need', 'NN'), ('help', 'VBZ'), ('a', 'DT'), ('our', 'PRP$'), ('house', 'NN'), ('have', 'VBP'), ('been', 'VBN'), ('destroyed', 'VBN'), ('at', 'IN'), ('delmas', 'NN')]
# [('we', 'PRP'), ('are', 'VBP'), ('now', 'RB'), ('staying', 'VBG'), ('at', 'IN'), ('thomassin', 'NN'), ('42', 'CD')]
# [('the', 'DT'), ('premier', 'NN'), ('stressed', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('ha', 'VBD'), ('been', 'VBN'), ('a', 'DT'), ('tradition', 'NN'), ('for', 'IN'), ('the', 'DT'), ('chinese', 'JJ'), ('nation', 'NN'), ('and', 'CC'), ('a', 'DT'), ('socialistic', 'JJ'), ('advantage', 'NN'), ('to', 'TO'), ('support', 'VB'), ('each', 'DT'), ('other', 'JJ'), ('and', 'CC'), ('make', 'VB'), ('a', 'DT'), ('united', 'JJ'), ('effort', 'NN'), ('to', 'TO'), ('help', 'VB'), ('those', 'DT'), ('in', 'IN'), ('difficulty', 'NN')]
# [('he', 'PRP'), ('further', 'RB'), ('hoped', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('recent', 'JJ'), ('increased', 'VBN'), ('participation', 'NN'), ('by', 'IN'), ('the', 'DT'), ('united', 'JJ'), ('state', 'NN'), ('in', 'IN'), ('climate', 'NN'), ('debate', 'NN'), ('indicated', 'VBD'), ('it', 'PRP'), ('intention', 'NN'), ('to', 'TO'), ('play', 'VB'), ('a', 'DT'), ('major', 'JJ'), ('role', 'NN')]
# [('we', 'PRP'), ('need', 'VBP'), ('help', 'VB'), ('in', 'IN'), ('croix', 'NN'), ('de', 'FW'), ('bouquet', 'FW'), ('call', 'VB'), ('me', 'PRP'), ('for', 'IN'), ('more', 'JJR'), ('info', 'NN')]
# [('poliomyelitis', 'NN'), ('according', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('world', 'NN'), ('initiative', 'NN'), ('for', 'IN'), ('the', 'DT'), ('eradication', 'NN'), ('of', 'IN'), ('polio4', 'NN'), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('potential', 'JJ'), ('threat', 'NN'), ('of', 'IN'), ('a', 'DT'), ('polio', 'JJ'), ('epidemic', 'NN'), ('in', 'IN'), ('west', 'NN'), ('africa', 'NN')]
# [('note', 'NN'), ('this', 'DT'), ('message', 'NN'), ('is', 'VBZ'), ('outside', 'IN'), ('of', 'IN'), ('our', 'PRP$'), ('work', 'NN')]
# [('wherw', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('venezuela', 'JJ'), ('embassy', 'NN')]
# [('this', 'DT'), ('storm', 'NN'), ('need', 'NN'), ('to', 'TO'), ('come', 'VB'), ('already', 'RB'), ('damn', 'VB')]
# [('major', 'JJ'), ('quake', 'NN'), ('hit', 'VBD'), ('haiti', 'RB'), ('many', 'JJ'), ('casualty', 'NN'), ('expected', 'VBN'), ('port', 'NN'), ('au', 'NN'), ('prince', 'NN'), ('haiti', 'NN'), ('ap', 'VBZ'), ('a', 'DT'), ('powerful', 'JJ'), ('earthquake', 'NN'), ('struck', 'VBD'), ('h', 'JJ'), ('http', 'NN'), ('ow', 'NN'), ('ly', 'VBD'), ('16kkut', 'CD')]
# [('note', 'NN'), ('i', 'NN'), ('always', 'RB'), ('translate', 'VB'), ('this', 'DT'), ('message', 'NN')]
# [('it', 'PRP'), ('s', 'VBD'), ('important', 'JJ'), ('because', 'IN'), ('those', 'DT'), ('person', 'NN'), ('don', 'VBP'), ('t', 'JJ'), ('get', 'VB'), ('any', 'DT'), ('help', 'NN')]
# [('pfizer', 'NN'), ('s', 'NN'), ('global', 'JJ'), ('effort', 'NN'), ('against', 'IN'), ('trachoma', 'JJ'), ('malaria', 'NNS'), ('and', 'CC'), ('hiv', 'NN'), ('aid', 'NN'), ('tested', 'VBD'), ('it', 'PRP'), ('partnership', 'NN'), ('with', 'IN'), ('unicef', 'PDT'), ('the', 'DT'), ('world', 'NN'), ('health', 'NN'), ('organization', 'NN'), ('who', 'WP'), ('and', 'CC'), ('others', 'NNS')]
# [('assistance', 'NN'), ('with', 'IN'), ('repair', 'NN'), ('of', 'IN'), ('the', 'DT'), ('damaged', 'VBN'), ('bengkulu', 'NN'), ('city', 'NN'), ('water', 'NN'), ('treatment', 'NN'), ('plant', 'NN'), ('and', 'CC'), ('water', 'NN'), ('reticulation', 'NN'), ('system', 'NN')]
# [('last', 'JJ'), ('year', 'NN'), ('during', 'IN'), ('the', 'DT'), ('meeting', 'NN'), ('of', 'IN'), ('the', 'DT'), ('conference', 'NN'), ('of', 'IN'), ('the', 'DT'), ('party', 'NN'), ('to', 'TO'), ('the', 'DT'), ('convention', 'NN'), ('on', 'IN'), ('biological', 'JJ'), ('diversity', 'NN'), ('government', 'NN'), ('worldwide', 'NN'), ('had', 'VBD'), ('committed', 'VBN'), ('to', 'TO'), ('restoring', 'VBG'), ('15', 'CD'), ('per', 'IN'), ('cent', 'NN'), ('of', 'IN'), ('their', 'PRP$'), ('degraded', 'JJ'), ('ecosystem', 'NN'), ('by', 'IN'), ('2020', 'CD'), ('he', 'PRP'), ('said', 'VBD')]
# [('it', 'PRP'), ('wa', 'VBZ'), ('very', 'RB'), ('windy', 'JJ'), ('and', 'CC'), ('there', 'EX'), ('were', 'VBD'), ('heavy', 'JJ'), ('thunderstorm', 'NN')]
# [('afghan', 'RB'), ('civil', 'JJ'), ('society', 'NN'), ('representative', 'NN'), ('told', 'VBD'), ('irin', 'NN'), ('on', 'IN'), ('wednesday', 'NN'), ('that', 'IN'), ('the', 'DT'), ('afghan', 'NN'), ('were', 'VBD'), ('also', 'RB'), ('concerned', 'VBN'), ('about', 'IN'), ('rampant', 'JJ'), ('violence', 'NN'), ('in', 'IN'), ('northern', 'JJ'), ('afghanistan', 'NN'), ('coupled', 'VBN'), ('with', 'IN'), ('a', 'DT'), ('fear', 'NN'), ('of', 'IN'), ('errant', 'JJ'), ('american', 'JJ'), ('bomb', 'NN'), ('such', 'PDT'), ('a', 'DT'), ('those', 'DT'), ('which', 'WDT'), ('killed', 'VBD'), ('dozen', 'NN'), ('of', 'IN'), ('civilian', 'NN'), ('a', 'DT'), ('week', 'NN'), ('ago', 'RB')]
# [('we', 'PRP'), ('cannnot', 'VBP'), ('stay', 'VB'), ('without', 'IN'), ('eating', 'VBG')]
# [('we', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('cook', 'VB')]
# [('please', 'NN'), ('intercede', 'NN'), ('for', 'IN'), ('u', 'NN')]
# [('we', 'PRP'), ('need', 'VBP'), ('help', 'VB')]
# [('where', 'WRB'), ('is', 'VBZ'), ('the', 'DT'), ('card', 'NN'), ('distribution', 'NN'), ('for', 'IN'), ('food', 'NN')]
# [('imd', 'NN'), ('s', 'VBZ'), ('weather', 'JJR'), ('report', 'NN'), ('a', 'DT'), ('on', 'IN'), ('30', 'CD'), ('06', 'CD'), ('2005', 'CD'), ('at', 'IN'), ('0800', 'CD'), ('hr', 'NN'), ('read', 'VBD'), ('a', 'DT'), ('follows', 'VBZ')]
# [('the', 'DT'), ('storm', 'NN'), ('destroyed', 'VBD'), ('275', 'CD'), ('000', 'CD'), ('acre', 'NN'), ('111', 'CD'), ('288', 'CD'), ('hectare', 'NN'), ('of', 'IN'), ('farmland', 'NN'), ('breached', 'VBD'), ('600', 'CD'), ('irrigation', 'NN'), ('canal', 'NN'), ('swept', 'VBD'), ('away', 'RB'), ('hundred', 'VBN'), ('of', 'IN'), ('bridge', 'NN'), ('and', 'CC'), ('road', 'NN'), ('and', 'CC'), ('snapped', 'VBD'), ('electricity', 'NN'), ('supply', 'NN'), ('across', 'IN'), ('wide', 'JJ'), ('swathe', 'NN'), ('of', 'IN'), ('the', 'DT'), ('state', 'NN')]
# [('doe', 'NN'), ('dgi', 'NN'), ('began', 'VBD'), ('to', 'TO'), ('give', 'VB'), ('identification', 'NN'), ('card', 'NN'), ('or', 'CC'), ('passport', 'NN'), ('to', 'TO'), ('spare', 'VB'), ('already', 'RB'), ('thank', 'VB'), ('you', 'PRP'), ('very', 'RB'), ('much', 'RB')]
# [('over', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('five', 'CD'), ('year', 'NN'), ('usaid', 'NN'), ('funded', 'VBD'), ('senegalese', 'JJ'), ('scientist', 'NN'), ('in', 'IN'), ('researching', 'VBG'), ('developing', 'NN'), ('and', 'CC'), ('testing', 'VBG'), ('biopesticides', 'NNS'), ('that', 'WDT'), ('can', 'MD'), ('be', 'VB'), ('used', 'VBN'), ('to', 'TO'), ('ward', 'VB'), ('off', 'RP'), ('locust', 'NN'), ('and', 'CC'), ('grasshopper', 'NN')]
# [('level', 'NN'), ('of', 'IN'), ('chronic', 'JJ'), ('malnutrition', 'NN'), ('and', 'CC'), ('anaemia', 'NN'), ('continue', 'VBP'), ('to', 'TO'), ('worsen', 'VB')]
# [('in', 'IN'), ('that', 'DT'), ('context', 'NN'), ('she', 'PRP'), ('welcomed', 'VBD'), ('the', 'DT'), ('vote', 'NN'), ('by', 'IN'), ('the', 'DT'), ('assembly', 'NN'), ('on', 'IN'), ('resolution', 'NN'), ('68', 'CD'), ('304', 'CD'), ('to', 'TO'), ('restructure', 'VB'), ('the', 'DT'), ('foreign', 'JJ'), ('debt', 'NN'), ('of', 'IN'), ('all', 'DT'), ('country', 'NN')]
# [('the', 'DT'), ('tbilisi', 'NN'), ('youth', 'NN'), ('house', 'NN'), ('foundation', 'NN'), ('tyhf', 'NN'), ('in', 'IN'), ('tbilisi', 'JJ'), ('republic', 'NN'), ('of', 'IN'), ('georgia', 'NNS'), ('formerly', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('soviet', 'JJ'), ('union', 'NN'), ('is', 'VBZ'), ('helping', 'VBG'), ('disadvantaged', 'VBN'), ('youth', 'NN'), ('prepare', 'NN'), ('for', 'IN'), ('a', 'DT'), ('tough', 'JJ'), ('job', 'NN'), ('market', 'NN'), ('and', 'CC'), ('find', 'VB'), ('new', 'JJ'), ('hope', 'NN'), ('for', 'IN'), ('the', 'DT'), ('future', 'NN'), ('with', 'IN'), ('the', 'DT'), ('support', 'NN'), ('of', 'IN'), ('church', 'NN'), ('world', 'NN'), ('service', 'NN')]
# [('the', 'DT'), ('uae', 'JJ'), ('pap', 'NN'), ('administration', 'NN'), ('said', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('polio', 'NN'), ('vaccination', 'NN'), ('campaign', 'NN'), ('is', 'VBZ'), ('being', 'VBG'), ('carried', 'VBN'), ('out', 'RP'), ('on', 'IN'), ('schedule', 'NN'), ('with', 'IN'), ('the', 'DT'), ('fourth', 'JJ'), ('dose', 'NN'), ('expected', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('completed', 'VBN'), ('this', 'DT'), ('month', 'NN')]
# [('i', 'NN'), ('want', 'VBP'), ('to', 'TO'), ('help', 'VB'), ('clean', 'VB'), ('up', 'RP')]
# [('i', 'NN'), ('can', 'MD'), ('lift', 'VB'), ('heavy', 'JJ'), ('thing', 'NN'), ('and', 'CC'), ('don', 'VB'), ('t', 'NN'), ('mind', 'IN'), ('shuffling', 'VBG'), ('water', 'NN'), ('out', 'IN'), ('of', 'IN'), ('a', 'DT'), ('basement', 'NN')]
# [('video', 'NN'), ('and', 'CC'), ('fotos', 'NN'), ('you', 'PRP'), ('won', 'VBD'), ('t', 'NNS'), ('see', 'VBP'), ('on', 'IN'), ('cnn', 'NN'), ('from', 'IN'), ('concepcion', 'NN'), ('chile', 'NN')]
# [('pray', 'NN'), ('for', 'IN'), ('them', 'PRP')]
# [('via', 'IN'), ('elsur', 'JJ'), ('url', 'JJ'), ('placeholder', 'NN')]
# [('and', 'CC'), ('the', 'DT'), ('overall', 'JJ'), ('number', 'NN'), ('of', 'IN'), ('death', 'NN'), ('attributed', 'VBN'), ('to', 'TO'), ('pro', 'VB'), ('government', 'NN'), ('force', 'NN'), ('which', 'WDT'), ('include', 'VBP'), ('the', 'DT'), ('ana', 'NN'), ('afghan', 'JJ'), ('national', 'JJ'), ('army', 'NN'), ('anp', 'NN'), ('afghan', 'IN'), ('national', 'JJ'), ('police', 'NNS'), ('nd', 'JJ'), ('national', 'JJ'), ('directorate', 'NN'), ('of', 'IN'), ('security', 'NN'), ('and', 'CC'), ('international', 'JJ'), ('military', 'JJ'), ('force', 'NN'), ('marginally', 'RB'), ('exceeds', 'VBZ'), ('that', 'IN'), ('caused', 'VBN'), ('by', 'IN'), ('antigovernment', 'JJ'), ('force', 'NN')]
# [('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('know', 'VB'), ('if', 'IN'), ('school', 'NN'), ('will', 'MD'), ('resume', 'VB'), ('again', 'RB'), ('or', 'CC'), ('not', 'RB')]
# [('help', 'VB'), ('me', 'PRP'), ('because', 'IN'), ('i', 'NN'), ('am', 'VBP'), ('alone', 'RB'), ('during', 'IN'), ('the', 'DT'), ('earthquake', 'NN'), ('problem', 'NN')]
# [('sometimes', 'RB'), ('i', 'JJ'), ('think', 'VBP'), ('about', 'IN'), ('committing', 'VBG'), ('suicide', 'NN')]
# [('someone', 'NN'), ('told', 'VBD'), ('me', 'PRP'), ('that', 'IN'), ('the', 'DT'), ('central', 'JJ'), ('tray', 'NN'), ('will', 'MD'), ('not', 'RB'), ('hit', 'VB'), ('by', 'IN'), ('the', 'DT'), ('earthquake', 'NN'), ('give', 'VB'), ('me', 'PRP'), ('some', 'DT'), ('information', 'NN'), ('please', 'NN')]
# [('lds', 'NNS'), ('ha', 'VBP'), ('received', 'VBN'), ('report', 'NN'), ('of', 'IN'), ('damage', 'NN'), ('to', 'TO'), ('school', 'NN'), ('roof', 'NN'), ('clinic', 'NN'), ('and', 'CC'), ('toilet', 'NN'), ('in', 'IN'), ('their', 'PRP$'), ('operational', 'JJ'), ('area', 'NN'), ('in', 'IN'), ('addition', 'NN'), ('to', 'TO'), ('road', 'NN'), ('bridge', 'NN'), ('and', 'CC'), ('electrical', 'JJ'), ('transformer', 'NN'), ('which', 'WDT'), ('ha', 'VBZ'), ('severely', 'RB'), ('hampered', 'JJ'), ('communication', 'NN')]
# [('i', 'NN'), ('m', 'VBP'), ('a', 'DT'), ('agriculture', 'NN'), ('technician', 'NN')]
# [('i', 'JJ'), ('live', 'VBP'), ('in', 'IN'), ('dame', 'NN'), ('marie', 'NN'), ('i', 'NN'), ('would', 'MD'), ('like', 'VB'), ('you', 'PRP'), ('to', 'TO'), ('think', 'VB'), ('of', 'IN'), ('me', 'PRP')]
# [('thank', 'NN'), ('you', 'PRP'), ('for', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('information', 'NN'), ('you', 'PRP'), ('gave', 'VBD'), ('me', 'PRP')]
# [('this', 'DT'), ('could', 'MD'), ('be', 'VB'), ('a', 'DT'), ('consequence', 'NN'), ('of', 'IN'), ('the', 'DT'), ('unpurified', 'JJ'), ('water', 'NN'), ('she', 'PRP'), ('drink', 'VBZ'), ('or', 'CC'), ('a', 'DT'), ('psychosomatic', 'JJ'), ('reaction', 'NN'), ('to', 'TO'), ('the', 'DT'), ('stress', 'NN'), ('of', 'IN'), ('her', 'PRP$'), ('new', 'JJ'), ('living', 'NN'), ('condition', 'NN')]
# [('we', 'PRP'), ('are', 'VBP'), ('hungry', 'JJ'), ('our', 'PRP$'), ('home', 'NN'), ('ha', 'NN'), ('been', 'VBN'), ('crushed', 'VBN'), ('our', 'PRP$'), ('family', 'NN'), ('who', 'WP'), ('were', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('city', 'NN'), ('come', 'VBP'), ('find', 'VBP'), ('u', 'JJ')]
# [('wfp', 'NN'), ('also', 'RB'), ('seek', 'VBP'), ('to', 'TO'), ('create', 'VB'), ('communal', 'JJ'), ('asset', 'NN'), ('which', 'WDT'), ('could', 'MD'), ('further', 'RB'), ('improve', 'VB'), ('food', 'NN'), ('production', 'NN'), ('health', 'NN'), ('and', 'CC'), ('living', 'NN'), ('condition', 'NN'), ('through', 'IN'), ('the', 'DT'), ('rehabilitation', 'NN'), ('of', 'IN'), ('social', 'JJ'), ('infrastructure', 'NN'), ('drinking', 'NN'), ('water', 'NN'), ('and', 'CC'), ('sewerage', 'NN'), ('system', 'NN'), ('housing', 'NN'), ('and', 'CC'), ('public', 'JJ'), ('building', 'NN'), ('repair', 'NN'), ('and', 'CC'), ('construction', 'NN')]
# [('in', 'IN'), ('the', 'DT'), ('area', 'NN'), ('that', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('we', 'PRP'), ('don', 'JJ'), ('t', 'JJ'), ('find', 'NN'), ('nothing', 'NN')]
# [('the', 'DT'), ('delivery', 'NN'), ('man', 'NN'), ('don', 'VBZ'), ('t', 'JJ'), ('give', 'JJ'), ('u', 'NN'), ('the', 'DT'), ('card', 'NN')]
# [('we', 'PRP'), ('are', 'VBP'), ('in', 'IN'), ('beten', 'NNS'), ('to', 'TO'), ('find', 'VB'), ('the', 'DT'), ('card', 'NN'), ('you', 'PRP'), ('must', 'MD'), ('contact', 'VB'), ('me', 'PRP')]
# [('thanks', 'NNS')]
# [('i', 'NN'), ('am', 'VBP'), ('a', 'DT'), ('student', 'NN'), ('and', 'CC'), ('i', 'VB'), ('need', 'VBP'), ('a', 'DT'), ('job', 'NN'), ('tell', 'VB'), ('me', 'PRP'), ('where', 'WRB'), ('to', 'TO'), ('give', 'VB'), ('my', 'PRP$'), ('cv', 'NN'), ('thanks', 'NNS')]
# [('it', 'PRP'), ('ha', 'VBD'), ('been', 'VBN'), ('quite', 'RB'), ('a', 'DT'), ('while', 'NN'), ('i', 'NN'), ('did', 'VBD'), ('not', 'RB'), ('receive', 'VB'), ('your', 'PRP$'), ('message', 'NN'), ('from', 'IN'), ('you', 'PRP')]
# [('even', 'RB'), ('at', 'IN'), ('the', 'DT'), ('child', 'NN'), ('s', 'JJ'), ('hospital', 'NN'), ('in', 'IN'), ('the', 'DT'), ('heart', 'NN'), ('of', 'IN'), ('lagos', 'NN'), ('i', 'NN'), ('had', 'VBD'), ('to', 'TO'), ('donate', 'VB'), ('the', 'DT'), ('electrical', 'JJ'), ('socket', 'NN'), ('needed', 'VBD'), ('to', 'TO'), ('operate', 'VB'), ('the', 'DT'), ('phototherapy', 'NN'), ('equipment', 'NN')]
# [('somali', 'NN'), ('who', 'WP'), ('crossed', 'VBD'), ('into', 'IN'), ('neighbouring', 'JJ'), ('country', 'NN'), ('are', 'VBP'), ('being', 'VBG'), ('accommodated', 'VBN'), ('in', 'IN'), ('overcrowded', 'JJ'), ('refugee', 'NN'), ('camp', 'NN')]
# [('earlier', 'RBR'), ('report', 'NN'), ('said', 'VBD'), ('bao', 'NN'), ('developed', 'VBD'), ('a', 'DT'), ('fever', 'NN'), ('on', 'IN'), ('the', 'DT'), ('domestic', 'JJ'), ('flight', 'NN'), ('accompanied', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('sore', 'NN'), ('throat', 'NN'), ('coughing', 'VBG'), ('nasal', 'JJ'), ('congestion', 'NN'), ('and', 'CC'), ('sneezing', 'NN')]
# [('the', 'DT'), ('government', 'NN'), ('of', 'IN'), ('canada', 'NN'), ('announces', 'NNS'), ('that', 'IN'), ('it', 'PRP'), ('will', 'MD'), ('match', 'VB'), ('donation', 'NN'), ('made', 'VBN'), ('by', 'IN'), ('individual', 'JJ'), ('canadian', 'JJ'), ('to', 'TO'), ('non', 'VB'), ('governmental', 'JJ'), ('organization', 'NN'), ('already', 'RB'), ('involved', 'VBN'), ('in', 'IN'), ('responding', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('disaster', 'NN')]
# [('support', 'NN'), ('and', 'CC'), ('supervise', 'NN'), ('rubbish', 'JJ'), ('collection', 'NN'), ('and', 'CC'), ('drainage', 'NN'), ('clearing', 'NN'), ('at', 'IN'), ('identified', 'VBN'), ('idp', 'NN'), ('camp', 'NN'), ('by', 'IN'), ('supplying', 'VBG'), ('of', 'IN'), ('tool', 'NN'), ('and', 'CC'), ('material', 'NN'), ('renting', 'VBG'), ('additional', 'JJ'), ('haul', 'NN'), ('away', 'RB'), ('vehicle', 'NN'), ('for', 'IN'), ('the', 'DT'), ('local', 'JJ'), ('authority', 'NN')]
# [('the', 'DT'), ('rainy', 'NN'), ('and', 'CC'), ('stormy', 'NN'), ('season', 'NN'), ('in', 'IN'), ('2010', 'CD'), ('is', 'VBZ'), ('forecasted', 'VBN'), ('to', 'TO'), ('develop', 'VB'), ('in', 'IN'), ('a', 'DT'), ('very', 'RB'), ('complicated', 'JJ'), ('manner', 'NN')]
# [('kindly', 'RB'), ('note', 'VBP'), ('that', 'IN'), ('no', 'DT'), ('tax', 'NN'), ('exemption', 'NN'), ('will', 'MD'), ('be', 'VB'), ('accorded', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('appeal', 'NN')]
# [('hit', 'VBN'), ('u', 'JJ'), ('and', 'CC'), ('some', 'DT'), ('of', 'IN'), ('u', 'NNS'), ('have', 'VBP'), ('broken', 'VBN'), ('arm', 'NN'), ('and', 'CC'), ('broken', 'JJ'), ('leg', 'NN'), ('please', 'NN'), ('come', 'VB'), ('help', 'NN'), ('u', 'NN'), ('because', 'IN'), ('we', 'PRP'), ('are', 'VBP'), ('dying', 'VBG'), ('in', 'IN'), ('the', 'DT'), ('cold', 'NN')]
# [('many', 'JJ'), ('house', 'NN'), ('present', 'JJ'), ('undamaged', 'JJ'), ('facade', 'NN'), ('hiding', 'NN'), ('collapsed', 'VBD'), ('roof', 'NN'), ('and', 'CC'), ('wall', 'NN')]
# [('please', 'NN'), ('i', 'NN'), ('want', 'VBP'), ('to', 'TO'), ('receive', 'VB'), ('all', 'DT'), ('important', 'JJ'), ('news', 'NN')]
# [('hi', 'VB'), ('my', 'PRP$'), ('little', 'JJ'), ('sherly', 'RB'), ('good', 'JJ'), ('night', 'NN')]
# [('kiss', 'JJ'), ('kiss', 'NN'), ('kiss', 'NN')]
# [('where', 'WRB'), ('they', 'PRP'), ('give', 'VBP'), ('the', 'DT'), ('electoral', 'JJ'), ('card', 'NN')]
# [('i', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('problem', 'NN')]
# [('i', 'NN'), ('lost', 'VBD'), ('my', 'PRP$'), ('four', 'CD'), ('kid', 'NN'), ('i', 'NN'), ('m', 'VBP'), ('broken', 'VBN'), ('my', 'PRP$'), ('wife', 'NN'), ('is', 'VBZ'), ('crazy', 'JJ')]
# [('can', 'MD'), ('you', 'PRP'), ('help', 'VB'), ('me', 'PRP')]
# [('good', 'JJ'), ('evening', 'NN'), ('when', 'WRB'), ('you', 'PRP'), ('active', 'JJ'), ('50', 'CD'), ('g', 'NN'), ('sm', 'NN'), ('is', 'VBZ'), ('it', 'PRP'), ('for', 'IN'), ('international', 'JJ'), ('thank', 'NN'), ('you', 'PRP')]
# [('the', 'DT'), ('route', 'JJ'), ('north', 'NN'), ('and', 'CC'), ('south', 'NN'), ('can', 'MD'), ('handle', 'VB'), ('two', 'CD'), ('lane', 'NN'), ('traffic', 'NN'), ('on', 'IN'), ('most', 'JJS'), ('of', 'IN'), ('the', 'DT'), ('coastal', 'JJ'), ('road', 'NN'), ('from', 'IN'), ('e', '$'), ('04', 'CD'), ('b043', 'NN'), ('53', 'CD'), ('8', 'CD'), ('n', 'JJ'), ('95', 'CD'), ('b030', 'NN'), ('27', 'CD'), ('4', 'CD'), ('to', 'TO'), ('e', 'VB'), ('04', 'CD'), ('b032', 'NN'), ('32', 'CD'), ('4', 'CD'), ('n', 'JJ'), ('95', 'CD'), ('b043', 'NN'), ('02', 'CD'), ('0', 'CD'), ('with', 'IN'), ('area', 'NN'), ('that', 'WDT'), ('are', 'VBP'), ('reduced', 'VBN'), ('to', 'TO'), ('single', 'JJ'), ('lane', 'NN'), ('traffic', 'NN'), ('which', 'WDT'), ('in', 'IN'), ('most', 'JJS'), ('case', 'NN'), ('are', 'VBP'), ('small', 'JJ'), ('timber', 'NNP'), ('bridge', 'NN'), ('that', 'WDT'), ('have', 'VBP'), ('been', 'VBN'), ('recently', 'RB'), ('replaced', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('tni', 'NN')]
# [('this', 'DT'), ('crisis', 'NN'), ('come', 'VB'), ('a', 'DT'), ('a', 'DT'), ('result', 'NN'), ('of', 'IN'), ('swarming', 'VBG'), ('locust', 'NN'), ('and', 'CC'), ('extreme', 'JJ'), ('drought', 'NN'), ('that', 'WDT'), ('have', 'VBP'), ('decimated', 'VBN'), ('farm', 'NN'), ('and', 'CC'), ('brought', 'JJ'), ('agricultural', 'JJ'), ('production', 'NN'), ('to', 'TO'), ('a', 'DT'), ('standstill', 'NN')]
# [('it', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('implemented', 'VBN'), ('in', 'IN'), ('2013', 'CD'), ('and', 'CC'), ('2014', 'CD'), ('and', 'CC'), ('will', 'MD'), ('provide', 'VB'), ('specialized', 'JJ'), ('nutritious', 'JJ'), ('food', 'NN'), ('a', 'DT'), ('treatment', 'NN'), ('for', 'IN'), ('child', 'NN'), ('aged', 'VBD'), ('6', 'CD'), ('59', 'CD'), ('month', 'NN'), ('with', 'IN'), ('moderate', 'JJ'), ('acute', 'NN'), ('malnutrition', 'NN'), ('mam', 'VBZ'), ('a', 'DT'), ('well', 'RB'), ('a', 'DT'), ('malnourished', 'VBN'), ('pregnant', 'NN'), ('and', 'CC'), ('lactating', 'VBG'), ('woman', 'NN'), ('plws', 'NN'), ('and', 'CC'), ('food', 'NN'), ('support', 'NN'), ('to', 'TO'), ('mother', 'VB'), ('whose', 'WP$'), ('child', 'NN'), ('hospitalized', 'VBN'), ('for', 'IN'), ('severe', 'JJ'), ('acute', 'NN'), ('malnutrition', 'NN')]
# [('i', 'NN'), ('see', 'VBP'), ('bad', 'JJ'), ('news', 'NN')]
# [('we', 'PRP'), ('are', 'VBP'), ('under', 'IN'), ('tent', 'NN')]
# [('instead', 'RB'), ('for', 'IN'), ('food', 'NN'), ('cost', 'NN'), ('to', 'TO'), ('decrease', 'VB'), ('it', 'PRP'), ('s', 'JJ'), ('increasing', 'VBG')]
# [('what', 'WP'), ('do', 'VBP'), ('you', 'PRP'), ('think', 'VB'), ('we', 'PRP'), ('should', 'MD'), ('do', 'VB')]
# [('good', 'JJ'), ('afternoon', 'NN'), ('people', 'NNS'), ('in', 'IN'), ('petyon', 'JJ'), ('vil', 'NN'), ('and', 'CC'), ('gaba', 'JJ'), ('street', 'NN'), ('is', 'VBZ'), ('asking', 'VBG'), ('please', 'NN'), ('to', 'TO'), ('do', 'VB'), ('whatever', 'VB'), ('it', 'PRP'), ('take', 'VB'), ('to', 'TO'), ('see', 'VB'), ('if', 'IN'), ('they', 'PRP'), ('can', 'MD'), ('receive', 'VB'), ('some', 'DT'), ('aid', 'NN')]
# [('save', 'VB'), ('the', 'DT'), ('child', 'NN'), ('u', 'JJ'), ('sc', 'NN'), ('u', 'JJ'), ('drought', 'NN'), ('related', 'JJ'), ('relief', 'NN'), ('activity', 'NN'), ('in', 'IN'), ('a', 'DT'), ('range', 'NN'), ('of', 'IN'), ('sector', 'NN'), ('including', 'VBG'), ('health', 'NN'), ('with', 'IN'), ('a', 'DT'), ('focus', 'NN'), ('on', 'IN'), ('maternal', 'JJ'), ('and', 'CC'), ('child', 'JJ'), ('care', 'NN'), ('winterization', 'NN'), ('for', 'IN'), ('idp', 'NN'), ('and', 'CC'), ('cash', 'NN'), ('for', 'IN'), ('work', 'NN'), ('drought', 'NN'), ('activity', 'NN'), ('including', 'VBG'), ('well', 'RB'), ('and', 'CC'), ('kareze', 'VB'), ('repair', 'NN'), ('and', 'CC'), ('digging', 'NN'), ('and', 'CC'), ('wheat', 'NN'), ('seed', 'NN'), ('distribution', 'NN')]
# [('i', 'NN'), ('just', 'RB'), ('want', 'VB'), ('this', 'DT'), ('storm', 'NN'), ('to', 'TO'), ('hit', 'VB'), ('so', 'RB'), ('we', 'PRP'), ('have', 'VBP'), ('some', 'DT'), ('excitement', 'NN')]
# [('i', 'NN'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('know', 'VB'), ('when', 'WRB'), ('the', 'DT'), ('government', 'NN'), ('help', 'NN'), ('someone', 'NN'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('province', 'NN'), ('do', 'VBP'), ('they', 'PRP'), ('give', 'VB'), ('them', 'PRP'), ('a', 'DT'), ('job', 'NN')]
# [('goodnight', 'NN')]
# [('please', 'NN'), ('also', 'RB'), ('note', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('travel', 'NN'), ('schedule', 'NN'), ('made', 'VBD'), ('prior', 'RB'), ('to', 'TO'), ('the', 'DT'), ('trip', 'NN'), ('wa', 'NN'), ('not', 'RB'), ('adhered', 'VBN'), ('to', 'TO'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('great', 'JJ'), ('influence', 'NN'), ('of', 'IN'), ('the', 'DT'), ('climatic', 'JJ'), ('and', 'CC'), ('topographic', 'JJ'), ('condition', 'NN')]
# [('call', 'VB'), ('me', 'PRP'), ('when', 'WRB'), ('you', 'PRP'), ('get', 'VBP'), ('this', 'DT'), ('message', 'NN')]
# [('ouisck', 'NN'), ('please', 'NN'), ('share', 'NN'), ('out', 'IN'), ('a', 'DT'), ('i', 'NN'), ('made', 'VBD'), ('this', 'DT'), ('to', 'TO'), ('help', 'VB'), ('out', 'RP'), ('u', 'JJ'), ('from', 'IN'), ('nj', 'JJ'), ('ny', 'NN')]
# [('url', 'JJ'), ('placeholder', 'NN'), ('sandyhelpif', 'NN'), ('you', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('help', 'VB'), ('with', 'IN'), ('sandy', 'JJ'), ('relief', 'NN'), ('don', 'NN'), ('t', 'NN'), ('just', 'RB'), ('give', 'VB'), ('money', 'NN'), ('to', 'TO'), ('red', 'VB'), ('cross', 'NN')]
# [('please', 'VB'), ('do', 'VB'), ('some', 'DT'), ('research', 'NN'), ('1st', 'CD')]
# [('red', 'JJ'), ('cross', 'NN'), ('is', 'VBZ'), ('a', 'DT'), ('broken', 'JJ'), ('bureaucracy', 'NN')]
# [('project', 'NN'), ('output', 'NN'), ('to', 'TO'), ('rehabilitate', 'VB'), ('eight', 'CD'), ('primary', 'JJ'), ('school', 'NN'), ('including', 'VBG'), ('classroom', 'NN'), ('teacher', 'NN'), ('housing', 'NN'), ('and', 'CC'), ('bathroom', 'NN'), ('facility', 'NN'), ('to', 'TO'), ('government', 'NN'), ('standard', 'NN')]
# [('pewoden', 'JJ'), ('fifth', 'JJ'), ('section', 'NN'), ('of', 'IN'), ('the', 'DT'), ('departemen', 'NNS'), ('of', 'IN'), ('l', 'NN'), ('artibonite', 'NN'), ('is', 'VBZ'), ('lettin', 'JJ'), ('u', 'NN'), ('know', 'VBP'), ('today', 'NN'), ('the', 'DT'), ('plan', 'NN'), ('we', 'PRP'), ('have', 'VBP'), ('for', 'IN'), ('those', 'DT'), ('injured', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('eartquake', 'NN')]
# [('like', 'IN'), ('many', 'JJ'), ('of', 'IN'), ('those', 'DT'), ('in', 'IN'), ('p', 'NN')]
# [('we', 'PRP'), ('are', 'VBP'), ('trying', 'VBG'), ('to', 'TO'), ('prevent', 'VB'), ('such', 'JJ'), ('food', 'NN'), ('rioting', 'NN'), ('by', 'IN'), ('pumping', 'VBG'), ('more', 'JJR'), ('relief', 'JJ'), ('material', 'NN'), ('into', 'IN'), ('the', 'DT'), ('flood', 'NN'), ('hit', 'VBD'), ('area', 'NN'), ('said', 'VBD'), ('manoj', 'JJ'), ('kumar', 'NN'), ('srivastava', 'VBD'), ('the', 'DT'), ('state', 'NN'), ('disaster', 'NN'), ('management', 'NN'), ('secretary', 'NN')]
# [('hanoi', 'NN'), ('july', 'NN'), ('27', 'CD'), ('afp', 'IN'), ('the', 'DT'), ('death', 'NN'), ('toll', 'NN'), ('from', 'IN'), ('torrential', 'JJ'), ('storm', 'NN'), ('that', 'WDT'), ('lashed', 'VBD'), ('vietnam', 'RB'), ('s', 'JJ'), ('mountainous', 'JJ'), ('north', 'NN'), ('last', 'JJ'), ('week', 'NN'), ('ha', 'VBD'), ('risen', 'VBN'), ('to', 'TO'), ('36', 'CD'), ('but', 'CC'), ('another', 'DT'), ('17', 'CD'), ('people', 'NNS'), ('are', 'VBP'), ('missing', 'VBG'), ('and', 'CC'), ('feared', 'VBN'), ('dead', 'JJ'), ('official', 'NN'), ('said', 'VBD'), ('tuesday', 'JJ')]
# [('in', 'IN'), ('54', 'CD'), ('lamentin', 'JJ'), ('road', 'NN'), ('untill', 'RB'), ('now', 'RB'), ('we', 'PRP'), ('didn', 'VBP'), ('t', 'JJ'), ('receive', 'VBP'), ('any', 'DT'), ('help', 'NN')]
# [('road', 'NN'), ('off', 'IN'), ('of', 'IN'), ('200', 'CD'), ('2', 'CD'), ('to', 'TO'), ('south', 'VB'), ('of', 'IN'), ('central', 'JJ'), ('leogane', 'NN')]
# [('same', 'JJ'), ('road', 'NN'), ('that', 'WDT'), ('go', 'VBP'), ('to', 'TO'), ('sabouce', 'VB'), ('end', 'NN'), ('at', 'IN'), ('deslandes', 'NNS')]
# [('no', 'DT'), ('gps', 'NN'), ('coordinate', 'NN'), ('available', 'JJ'), ('from', 'IN'), ('here', 'RB')]
# [('rt', 'NN'), ('cnn', 'NN'), ('find', 'VB'), ('out', 'RP'), ('how', 'WRB'), ('you', 'PRP'), ('can', 'MD'), ('help', 'VB'), ('make', 'VB'), ('a', 'DT'), ('difference', 'NN'), ('to', 'TO'), ('haiti', 'VB'), ('u2019s', 'JJ'), ('earthquake', 'NN'), ('victim', 'NN'), ('please', 'NN'), ('visit', 'NN'), ('cnn', 'NN'), ('com', 'NN'), ('impact', 'NN')]
# [('the', 'DT'), ('team', 'NN'), ('previously', 'RB'), ('tackled', 'VBD'), ('two', 'CD'), ('other', 'JJ'), ('cholera', 'NN'), ('epidemic', 'NN'), ('in', 'IN'), ('kamanyola', 'NN'), ('and', 'CC'), ('uvira', 'VB'), ('a', 'DT'), ('malaria', 'NN'), ('emergency', 'NN'), ('in', 'IN'), ('lulingo', 'NN'), ('and', 'CC'), ('two', 'CD'), ('measles', 'NNS'), ('emergency', 'NN'), ('one', 'CD'), ('in', 'IN'), ('kitutu', 'NN'), ('and', 'CC'), ('another', 'DT'), ('in', 'IN'), ('bunyakiri', 'NN'), ('which', 'WDT'), ('included', 'VBD'), ('a', 'DT'), ('vaccination', 'NN'), ('campaign', 'NN'), ('for', 'IN'), ('65', 'CD'), ('000', 'CD'), ('child', 'NN')]
# [('salutation', 'NN')]
# [('thank', 'NN'), ('you', 'PRP'), ('very', 'RB'), ('much', 'RB'), ('for', 'IN'), ('all', 'DT'), ('your', 'PRP$'), ('good', 'JJ'), ('advice', 'NN'), ('about', 'IN'), ('health', 'NN'), ('that', 'IN'), ('you', 'PRP'), ('send', 'VBP'), ('me', 'PRP')]
# [('the', 'DT'), ('only', 'JJ'), ('thing', 'NN'), ('always', 'RB'), ('remind', 'VBP'), ('that', 'IN'), ('i', 'NN'), ('have', 'VBP'), ('urgent', 'JJ'), ('need', 'NN')]
# [('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('modification', 'NN'), ('which', 'WDT'), ('made', 'VBD')]
# [('can', 'MD'), ('i', 'VB'), ('find', 'VB'), ('the', 'DT'), ('earthquake', 'NN'), ('at', 'IN'), ('five', 'CD'), ('or', 'CC'), ('six', 'CD'), ('richter', 'NN')]
# [('the', 'DT'), ('u', 'JJ'), ('say', 'VBP'), ('it', 'PRP'), ('regret', 'VBZ'), ('the', 'DT'), ('extension', 'NN'), ('of', 'IN'), ('president', 'NN'), ('karimov', 'NNS'), ('s', 'JJ'), ('term', 'NN'), ('of', 'IN'), ('office', 'NN')]
# [('bishkek', 'RB'), ('6', 'CD'), ('october', 'JJ'), ('2008', 'CD'), ('irin', 'NN'), ('an', 'DT'), ('earthquake', 'NN'), ('that', 'WDT'), ('jolted', 'VBD'), ('southern', 'JJ'), ('kyrgyzstan', 'NN'), ('on', 'IN'), ('the', 'DT'), ('evening', 'NN'), ('of', 'IN'), ('5', 'CD'), ('october', 'NN'), ('killed', 'VBN'), ('at', 'IN'), ('least', 'JJS'), ('70', 'CD'), ('people', 'NNS'), ('and', 'CC'), ('destroyed', 'VBN'), ('over', 'IN'), ('100', 'CD'), ('house', 'NN'), ('in', 'IN'), ('a', 'DT'), ('remote', 'JJ'), ('village', 'NN'), ('according', 'VBG'), ('to', 'TO'), ('official', 'NN')]
# [('the', 'DT'), ('inundation', 'NN'), ('and', 'CC'), ('landslide', 'JJ'), ('wa', 'NN'), ('caused', 'VBN'), ('by', 'IN'), ('recurrent', 'JJ'), ('torrential', 'JJ'), ('downpour', 'NN'), ('in', 'IN'), ('the', 'DT'), ('district', 'NN'), ('in', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('few', 'JJ'), ('day', 'NN'), ('a', 'DT'), ('the', 'DT'), ('local', 'JJ'), ('sirsha', 'NN'), ('river', 'NN'), ('had', 'VBD'), ('swamped', 'VBN'), ('different', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('sirsha', 'NN'), ('village', 'NN')]
# [('in', 'IN'), ('pyongyang', 'JJ'), ('electricity', 'NN'), ('is', 'VBZ'), ('unreliable', 'JJ'), ('with', 'IN'), ('power', 'NN'), ('surge', 'NN'), ('and', 'CC'), ('frequent', 'JJ'), ('cut', 'NN')]
# [('the', 'DT'), ('estimated', 'JJ'), ('loss', 'NN'), ('of', 'IN'), ('the', 'DT'), ('main', 'JJ'), ('crop', 'NN'), ('grown', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('area', 'NN'), ('affected', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('cyclone', 'NN'), ('are', 'VBP'), ('summarized', 'VBN'), ('in', 'IN'), ('table', 'JJ'), ('1', 'CD')]
# [('it', 'PRP'), ('s', 'VBZ'), ('not', 'RB'), ('a', 'DT'), ('hurricane', 'NN'), ('anymore', 'RB'), ('dummy', 'JJ')]
# [('it', 'PRP'), ('already', 'RB'), ('hit', 'VBD'), ('landfall', 'JJ')]
# [('it', 'PRP'), ('s', 'VBZ'), ('just', 'RB'), ('rain', 'NN'), ('and', 'CC'), ('wind', 'NN'), ('now', 'RB')]
# [('side', 'NN'), ('these', 'DT'), ('high', 'JJ'), ('tide', 'NN'), ('causing', 'VBG'), ('more', 'JJR'), ('floodsandy', 'JJ'), ('betta', 'NN'), ('not', 'RB'), ('mess', 'VB'), ('up', 'RP'), ('mah', 'NN'), ('halloween', 'NN')]
# [('the', 'DT'), ('all', 'DT'), ('people', 'NNS'), ('is', 'VBZ'), ('happy', 'JJ'), ('i', 'JJ'), ('thank', 'NN'), ('you', 'PRP'), ('so', 'RB'), ('much', 'RB'), ('united', 'JJ'), ('nation', 'NN'), ('i', 'NN'), ('m', 'VBP'), ('waiting', 'VBG'), ('for', 'IN'), ('anorther', 'NN'), ('helpyou', 'NN'), ('ll', 'VBP'), ('always', 'RB'), ('give', 'VBP'), ('order', 'NN'), ('everybody', 'NN'), ('love', 'VB'), ('you', 'PRP'), ('thanks', 'NNS')]
# [('rangeland', 'NN'), ('have', 'VBP'), ('benefited', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('favourable', 'JJ'), ('rain', 'NN'), ('and', 'CC'), ('livestock', 'NN'), ('condition', 'NN'), ('is', 'VBZ'), ('generally', 'RB'), ('good', 'JJ'), ('at', 'IN'), ('present', 'JJ')]
# [('some', 'DT'), ('of', 'IN'), ('the', 'DT'), ('nyc', 'JJ'), ('marathon', 'NN'), ('participant', 'NN'), ('will', 'MD'), ('be', 'VB'), ('running', 'VBG'), ('the', 'DT'), ('staten', 'JJ'), ('island', 'NN'), ('portion', 'NN'), ('with', 'IN'), ('backpack', 'NN'), ('full', 'JJ'), ('of', 'IN'), ('supply', 'NN')]
# [('priority', 'NN'), ('sandyhelpfirst', 'RB'), ('real', 'JJ'), ('meal', 'NN'), ('since', 'IN'), ('sandy', 'NN'), ('calzonezone', 'NN')]
# [('new', 'JJ'), ('york', 'NN'), ('with', 'IN'), ('support', 'NN'), ('from', 'IN'), ('the', 'DT'), ('united', 'JJ'), ('nation', 'NN'), ('development', 'NN'), ('programme', 'NN'), ('undp', 'NN'), ('and', 'CC'), ('the', 'DT'), ('global', 'JJ'), ('environment', 'NN'), ('facility', 'NN'), ('gef', 'NN'), ('sierra', 'VBD'), ('leone', 'CD'), ('ha', 'NN'), ('begun', 'VBN'), ('to', 'TO'), ('use', 'VB'), ('new', 'JJ'), ('environmentally', 'RB'), ('friendly', 'JJ'), ('sterilizing', 'VBG'), ('equipment', 'NN'), ('to', 'TO'), ('help', 'VB'), ('dispose', 'VB'), ('of', 'IN'), ('the', 'DT'), ('vast', 'JJ'), ('amount', 'NN'), ('of', 'IN'), ('contaminated', 'VBN'), ('protective', 'JJ'), ('equipment', 'NN'), ('and', 'CC'), ('infectious', 'JJ'), ('waste', 'NN'), ('generated', 'VBN'), ('in', 'IN'), ('treating', 'VBG'), ('ebola', 'NN'), ('patient', 'NN')]
# [('although', 'IN'), ('the', 'DT'), ('flood', 'NN'), ('situation', 'NN'), ('is', 'VBZ'), ('generally', 'RB'), ('stabilised', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('eastern', 'JJ'), ('and', 'CC'), ('south', 'JJ'), ('western', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('country', 'NN'), ('drought', 'NN'), ('and', 'CC'), ('and', 'CC'), ('occasional', 'JJ'), ('heatwaves', 'NNS'), ('ha', 'VBP'), ('hit', 'JJ'), ('eastern', 'JJ'), ('area', 'NN'), ('such', 'PDT'), ('a', 'DT'), ('jiangxi', 'NN'), ('province', 'NN')]
# [('a', 'DT'), ('people', 'NNS'), ('began', 'VBD'), ('to', 'TO'), ('make', 'VB'), ('a', 'DT'), ('slow', 'JJ'), ('transition', 'NN'), ('from', 'IN'), ('tent', 'NN'), ('and', 'CC'), ('big', 'JJ'), ('public', 'JJ'), ('building', 'NN'), ('to', 'TO'), ('other', 'JJ'), ('temporary', 'JJ'), ('shelter', 'NN'), ('inform', 'NN'), ('worked', 'VBD'), ('to', 'TO'), ('ensure', 'VB'), ('that', 'IN'), ('these', 'DT'), ('new', 'JJ'), ('shelter', 'NN'), ('provided', 'VBD'), ('access', 'NN'), ('to', 'TO'), ('electricity', 'NN'), ('water', 'NN'), ('and', 'CC'), ('sewage', 'NN'), ('and', 'CC'), ('garbage', 'NN'), ('disposal', 'NN'), ('and', 'CC'), ('that', 'DT'), ('child', 'NN'), ('could', 'MD'), ('start', 'VB'), ('returning', 'VBG'), ('to', 'TO'), ('school', 'NN')]
# [('oogie', 'JJ'), ('p', 'NNS'), ('hope', 'VBP'), ('u', 'JJ'), ('and', 'CC'), ('ur', 'JJ'), ('family', 'NN'), ('safe', 'JJ'), ('and', 'CC'), ('during', 'IN'), ('this', 'DT'), ('hurricane', 'NN')]
# [('because', 'IN'), ('new', 'JJ'), ('york', 'NN'), ('city', 'NN'), ('is', 'VBZ'), ('bad', 'JJ'), ('over', 'IN'), ('heresandy', 'NN'), ('it', 'PRP'), ('wack', 'VBZ'), ('rather', 'RB'), ('go', 'VB'), ('w', 'JJ'), ('spongebob', 'NN'), ('lmao', 'NN')]
# [('in', 'IN'), ('assam', 'NN'), ('and', 'CC'), ('arunachal', 'JJ'), ('pradesh', 'NN'), ('state', 'NN'), ('the', 'DT'), ('brahmaputra', 'NN'), ('river', 'NN'), ('crossed', 'VBD'), ('it', 'PRP'), ('highest', 'JJS'), ('flood', 'NN'), ('level', 'NN'), ('mark', 'NN'), ('breaching', 'VBG'), ('embankment', 'JJ'), ('changing', 'VBG'), ('course', 'NN'), ('and', 'CC'), ('destroying', 'VBG'), ('agricultural', 'JJ'), ('land', 'NN'), ('and', 'CC'), ('thousand', 'NN'), ('of', 'IN'), ('home', 'NN'), ('new', 'JJ'), ('delhi', 'NN'), ('television', 'NN'), ('reported', 'VBD')]
# [('all', 'DT'), ('our', 'PRP$'), ('heart', 'NN'), ('go', 'VB'), ('out', 'IN'), ('to', 'TO'), ('everyone', 'NN'), ('in', 'IN'), ('santiago', 'NN')]
# [('rt', 'NN'), ('myfoxdc', 'NN'), ('myfoxdc', 'NN'), ('photo', 'NN'), ('haiti', 'JJ'), ('earthquake', 'NN'), ('aftermath', 'IN'), ('a', 'DT'), ('major', 'JJ'), ('earthquake', 'NN'), ('left', 'VBD'), ('thousand', 'CD'), ('of', 'IN'), ('people', 'NNS'), ('in', 'IN'), ('and', 'CC'), ('around', 'IN'), ('nport', 'JJ'), ('o', 'NN'), ('http', 'NN'), ('tiny', 'JJ')]
# [('this', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('founder', 'NN'), ('of', 'IN'), ('college', 'NN'), ('jerusalem', 'NN'), ('in', 'IN'), ('la', 'NN'), ('gonave', 'VBP')]
# [('we', 'PRP'), ('are', 'VBP'), ('use', 'IN'), ('the', 'DT'), ('school', 'NN'), ('a', 'DT'), ('a', 'DT'), ('shelter', 'NN'), ('for', 'IN'), ('people', 'NNS'), ('to', 'TO'), ('sleep', 'VB'), ('in', 'IN')]
# [('these', 'DT'), ('people', 'NNS'), ('need', 'VBP'), ('aid', 'NN'), ('too', 'RB')]
# [('he', 'PRP'), ('then', 'RB'), ('explained', 'VBD'), ('plan', 'NN'), ('and', 'CC'), ('funding', 'JJ'), ('arrangement', 'NN'), ('now', 'RB'), ('in', 'IN'), ('place', 'NN'), ('for', 'IN'), ('infrastructure', 'NN'), ('reconstruction', 'NN'), ('in', 'IN'), ('the', 'DT'), ('affected', 'JJ'), ('sector', 'NN')]
# [('thank', 'NN'), ('you', 'PRP'), ('for', 'IN'), ('this', 'DT'), ('answer', 'VBZ'), ('the', 'DT'), ('fing', 'NN'), ('who', 'WP'), ('is', 'VBZ'), ('important', 'JJ'), ('i', 'NNS'), ('not', 'RB'), ('find', 'VB'), ('a', 'DT'), ('complete', 'JJ'), ('answer', 'NN'), ('do', 'VBP'), ('they', 'PRP'), ('forecast', 'VB'), ('a', 'DT'), ('volcan', 'JJ'), ('for', 'IN'), ('haiti', 'NN'), ('truly', 'NN')]
# [('two', 'CD'), ('triage', 'NN'), ('center', 'NN'), ('have', 'VBP'), ('been', 'VBN'), ('set', 'VBN'), ('up', 'RP'), ('one', 'CD'), ('at', 'IN'), ('the', 'DT'), ('football', 'NN'), ('field', 'NN'), ('where', 'WRB'), ('helicopter', 'NN'), ('can', 'MD'), ('land', 'VB'), ('and', 'CC'), ('the', 'DT'), ('other', 'JJ'), ('at', 'IN'), ('the', 'DT'), ('airport', 'NN')]
# [('ground', 'NN'), ('water', 'NN'), ('and', 'CC'), ('river', 'NN'), ('water', 'NN'), ('the', 'DT'), ('main', 'JJ'), ('drinking', 'NN'), ('water', 'NN'), ('source', 'NN'), ('in', 'IN'), ('the', 'DT'), ('camp', 'NN'), ('have', 'VBP'), ('also', 'RB'), ('been', 'VBN'), ('contaminated', 'VBN'), ('by', 'IN'), ('sewage', 'NN'), ('and', 'CC'), ('silt', 'NN'), ('washed', 'VBD'), ('into', 'IN'), ('river', 'NN'), ('ha', 'NN'), ('clogged', 'VBD'), ('up', 'RP'), ('water', 'NN'), ('filtration', 'NN'), ('system', 'NN'), ('the', 'DT'), ('fire', 'NN'), ('which', 'WDT'), ('raged', 'VBD'), ('for', 'IN'), ('a', 'DT'), ('month', 'NN'), ('also', 'RB'), ('killed', 'VBD'), ('more', 'JJR'), ('than', 'IN'), ('300', 'CD'), ('cattle', 'NNS'), ('and', 'CC'), ('contaminated', 'VBD'), ('the', 'DT'), ('air', 'NN'), ('causing', 'VBG'), ('respiratory', 'NN'), ('trouble', 'NN'), ('in', 'IN'), ('pech', 'JJ'), ('district', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('outlying', 'VBG'), ('village', 'VB'), ('the', 'DT'), ('station', 'NN'), ('added', 'VBD')]
# [('pakistan', 'NN'), ('musharraf', 'NN'), ('condemns', 'VBP'), ('religious', 'JJ'), ('hardliner', 'NN')]
# [('surono', 'NN'), ('who', 'WP'), ('said', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('evacuation', 'NN'), ('had', 'VBD'), ('started', 'VBN'), ('at', 'IN'), ('7', 'CD'), ('p', 'NNS'), ('m', 'JJ'), ('1200', 'CD'), ('gmt', 'NN'), ('warned', 'VBD'), ('that', 'IN'), ('resident', 'NN'), ('should', 'MD'), ('steer', 'VB'), ('clear', 'JJ'), ('of', 'IN'), ('river', 'NN'), ('near', 'IN'), ('the', 'DT'), ('volcano', 'NN'), ('in', 'IN'), ('case', 'NN'), ('of', 'IN'), ('flow', 'NN'), ('of', 'IN'), ('lahar', 'FW'), ('a', 'DT'), ('mix', 'NN'), ('of', 'IN'), ('hot', 'JJ'), ('stone', 'NN'), ('and', 'CC'), ('water', 'NN')]
# [('ophiabliu', 'IN'), ('it', 'PRP'), ('s', 'VBZ'), ('getting', 'VBG'), ('better', 'RBR'), ('santiago', 'JJ'), ('ha', 'NN'), ('no', 'DT'), ('problem', 'NN'), ('concepcion', 'NN'), ('ha', 'VBZ'), ('no', 'DT'), ('service', 'NN'), ('and', 'CC'), ('the', 'DT'), ('same', 'JJ'), ('with', 'IN'), ('other', 'JJ'), ('area', 'NN'), ('affected', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('earthqk', 'NN')]
# [('beijing', 'VBG'), ('june', 'NN'), ('28', 'CD'), ('afp', 'JJ'), ('china', 'NN'), ('tuesday', 'NN'), ('raised', 'VBD'), ('the', 'DT'), ('number', 'NN'), ('of', 'IN'), ('killed', 'VBN'), ('and', 'CC'), ('missing', 'VBG'), ('in', 'IN'), ('this', 'DT'), ('year', 'NN'), ('s', 'RB'), ('flood', 'VBD'), ('to', 'TO'), ('771', 'CD'), ('and', 'CC'), ('warned', 'VBD'), ('scorching', 'VBG'), ('temperature', 'NN'), ('in', 'IN'), ('previously', 'RB'), ('inundated', 'VBN'), ('area', 'NN'), ('create', 'NN'), ('ideal', 'JJ'), ('condition', 'NN'), ('for', 'IN'), ('infectious', 'JJ'), ('disease', 'NN')]
# [('i', 'JJ'), ('greet', 'NN'), ('you', 'PRP'), ('all', 'DT')]
# [('im', 'VB'), ('a', 'DT'), ('digicel', 'NN'), ('client', 'NN')]
# [('i', 'NN'), ('wa', 'VBP'), ('a', 'DT'), ('victim', 'NN'), ('of', 'IN'), ('the', 'DT'), ('quake', 'NN'), ('of', 'IN'), ('january', 'JJ'), ('12', 'CD')]
# [('i', 'JJ'), ('m', 'NN'), ('writing', 'VBG'), ('this', 'DT'), ('message', 'NN'), ('just', 'RB'), ('to', 'TO'), ('see', 'VB'), ('if', 'IN'), ('you', 'PRP'), ('guy', 'VBP'), ('can', 'MD'), ('help', 'VB')]
# [('since', 'IN'), ('i', 'NN'), ('am', 'VBP'), ('with', 'IN'), ('a', 'DT'), ('friend', 'NN'), ('of', 'IN'), ('mine', 'NN'), ('i', 'NN'), ('don', 'VBP'), ('t', 'NN'), ('know', 'VBP'), ('what', 'WP'), ('i', 'NN'), ('should', 'MD'), ('do', 'VB'), ('because', 'IN'), ('the', 'DT'), ('friend', 'NN'), ('ha', 'NN'), ('had', 'VBD'), ('me', 'PRP'), ('at', 'IN'), ('his', 'PRP$'), ('place', 'NN'), ('for', 'IN'), ('a', 'DT'), ('while', 'NN')]
# [('the', 'DT'), ('first', 'JJ'), ('individual', 'JJ'), ('donation', 'NN'), ('which', 'WDT'), ('wa', 'VBD'), ('200', 'CD'), ('000rmb', 'CD'), ('came', 'VBD'), ('on', 'IN'), ('feb', 'JJ'), ('1st', 'CD'), ('from', 'IN'), ('an', 'DT'), ('old', 'JJ'), ('gentleman', 'NN'), ('who', 'WP'), ('asked', 'VBD'), ('not', 'RB'), ('to', 'TO'), ('be', 'VB'), ('named', 'VBN')]
# ...
# [('our', 'PRP$'), ('team', 'NN'), ('in', 'IN'), ('pakistan', 'JJ'), ('spoke', 'NN'), ('to', 'TO'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('the', 'DT'), ('people', 'NNS'), ('affected', 'VBD'), ('and', 'CC'), ('found', 'VBD'), ('that', 'IN'), ('many', 'JJ'), ('family', 'NN'), ('were', 'VBD'), ('finding', 'VBG'), ('it', 'PRP'), ('hard', 'JJ'), ('to', 'TO'), ('look', 'VB'), ('after', 'IN'), ('their', 'PRP$'), ('child', 'NN'), ('at', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('time', 'NN'), ('a', 'DT'), ('trying', 'VBG'), ('to', 'TO'), ('rebuild', 'VB'), ('home', 'NN'), ('and', 'CC'), ('find', 'VB'), ('work', 'NN')]
# [('i', 'NN'), ('m', 'VBD'), ('a', 'DT'), ('driver', 'NN'), ('i', 'RB'), ('receive', 'VBP'), ('many', 'JJ'), ('message', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('very', 'RB'), ('important', 'JJ'), ('i', 'NN'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('find', 'VB'), ('a', 'DT'), ('job', 'NN'), ('of', 'IN'), ('driving', 'VBG')]
# [('good', 'JJ'), ('evening', 'NN'), ('it', 'PRP'), ('make', 'VBP'), ('a', 'DT'), ('very', 'RB'), ('long', 'JJ'), ('time', 'NN'), ('that', 'IN'), ('i', 'JJ'), ('didn', 'VBP'), ('t', 'JJ'), ('receive', 'VBP'), ('some', 'DT'), ('information', 'NN')]
# [('the', 'DT'), ('somali', 'NN'), ('diaspora', 'NNS'), ('have', 'VBP'), ('donated', 'VBN'), ('generously', 'RB'), ('and', 'CC'), ('the', 'DT'), ('first', 'JJ'), ('international', 'JJ'), ('aid', 'NN'), ('agency', 'NN'), ('qatar', 'NN'), ('charity', 'NN'), ('ha', 'NN'), ('provided', 'VBD'), ('emergency', 'NN'), ('supply', 'NN')]
# [('i', 'NN'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('know', 'VB'), ('some', 'DT'), ('information', 'NN'), ('on', 'IN'), ('daily', 'JJ'), ('activity', 'NN')]
# [('islandwide', 'RB'), ('540', 'CD'), ('000', 'CD'), ('home', 'NN'), ('were', 'VBD'), ('left', 'VBN'), ('temporarily', 'RB'), ('without', 'IN'), ('power', 'NN')]
# [('information', 'NN'), ('is', 'VBZ'), ('indeed', 'RB'), ('great', 'JJ'), ('but', 'CC'), ('whats', 'VBZ'), ('most', 'RBS'), ('important', 'JJ'), ('is', 'VBZ'), ('the', 'DT'), ('aide', 'NN'), ('so', 'IN'), ('we', 'PRP'), ('can', 'MD'), ('live', 'VB')]
# [('i', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('baby', 'NN'), ('and', 'CC'), ('i', 'NN'), ('have', 'VBP'), ('no', 'DT'), ('money', 'NN'), ('to', 'TO'), ('buy', 'VB'), ('milk', 'NN')]
# [('i', 'JJ'), ('d', 'VBP'), ('like', 'IN'), ('to', 'TO'), ('know', 'VB'), ('after', 'IN'), ('this', 'DT'), ('drama', 'NN'), ('will', 'MD'), ('there', 'RB'), ('be', 'VB'), ('anywhere', 'RB'), ('that', 'IN'), ('i', 'NN'), ('may', 'MD'), ('see', 'VB'), ('a', 'DT'), ('psychologist', 'NN'), ('who', 'WP'), ('maybe', 'RB'), ('available', 'JJ'), ('because', 'IN'), ('i', 'NN'), ('have', 'VBP')]
# [('what', 'WP'), ('should', 'MD'), ('we', 'PRP'), ('do', 'VB'), ('when', 'WRB'), ('people', 'NNS'), ('are', 'VBP'), ('talking', 'VBG'), ('back', 'RB'), ('to', 'TO'), ('u', 'VB'), ('thank', 'NN'), ('you', 'PRP')]
# [('according', 'VBG'), ('to', 'TO'), ('the', 'DT'), ('agreement', 'NN'), ('the', 'DT'), ('grant', 'NN'), ('will', 'MD'), ('be', 'VB'), ('used', 'VBN'), ('to', 'TO'), ('purchase', 'VB'), ('fertilizer', 'NN'), ('that', 'WDT'), ('aimed', 'VBD'), ('at', 'IN'), ('improving', 'VBG'), ('the', 'DT'), ('food', 'NN'), ('security', 'NN'), ('for', 'IN'), ('underprivileged', 'JJ'), ('farmer', 'NN'), ('in', 'IN'), ('the', 'DT'), ('country', 'NN')]
# [('my', 'PRP$'), ('love', 'NN'), ('i', 'NN'), ('can', 'MD'), ('t', 'VB'), ('live', 'VB'), ('without', 'IN'), ('you', 'PRP'), ('but', 'CC'), ('ala', 'VB')]
# [('tell', 'VB'), ('me', 'PRP'), ('why', 'WRB'), ('you', 'PRP'), ('are', 'VBP'), ('angry', 'JJ'), ('and', 'CC'), ('you', 'PRP'), ('are', 'VBP'), ('humiliating', 'VBG'), ('me', 'PRP')]
# [('i', 'NN'), ('can', 'MD'), ('t', 'VB'), ('you', 'PRP'), ('said', 'VBD'), ('word', 'NN'), ('but', 'CC'), ('that', 'IN'), ('s', 'VBP'), ('you', 'PRP')]
# [('the', 'DT'), ('teacher', 'NN'), ('are', 'VBP'), ('interrupted', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('boy', 'NN'), ('asking', 'VBG'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('the', 'DT'), ('toilet', 'NN'), ('he', 'PRP'), ('run', 'VBZ'), ('across', 'IN'), ('the', 'DT'), ('footpath', 'NN'), ('and', 'CC'), ('disappears', 'VBZ'), ('into', 'IN'), ('the', 'DT'), ('bush', 'NN')]
# [('an', 'DT'), ('ebola', 'NN'), ('outbreak', 'NN'), ('unprecedented', 'VBN'), ('in', 'IN'), ('term', 'NN'), ('of', 'IN'), ('it', 'PRP'), ('deadliness', 'NN'), ('and', 'CC'), ('it', 'PRP'), ('geographic', 'JJ'), ('reach', 'NN'), ('ha', 'NN'), ('been', 'VBN'), ('sweeping', 'VBG'), ('through', 'IN'), ('west', 'JJS'), ('africa', 'JJ'), ('hitting', 'VBG'), ('guinea', 'NN'), ('liberia', 'NNS'), ('and', 'CC'), ('sierra', 'VB'), ('leone', 'NN')]
# [('the', 'DT'), ('world', 'NN'), ('vision', 'NN'), ('project', 'NN'), ('call', 'NN'), ('for', 'IN'), ('the', 'DT'), ('construction', 'NN'), ('of', 'IN'), ('a', 'DT'), ('33', 'CD'), ('mile', 'JJ'), ('canal', 'NN'), ('to', 'TO'), ('divert', 'VB'), ('water', 'NN'), ('from', 'IN'), ('kenya', 'NN'), ('s', 'NN'), ('longest', 'JJS'), ('river', 'NN'), ('the', 'DT'), ('tana', 'NN'), ('to', 'TO'), ('recharge', 'VB'), ('aquifer', 'NN'), ('and', 'CC'), ('irrigate', 'NN'), ('land', 'NN'), ('surrounding', 'VBG'), ('the', 'DT'), ('city', 'NN'), ('of', 'IN'), ('dadaab', 'NN'), ('close', 'NN'), ('to', 'TO'), ('the', 'DT'), ('border', 'NN'), ('with', 'IN'), ('somalia', 'NNS')]
# [('haiti', 'NNS'), ('earthquake', 'NN'), ('what', 'WP'), ('we', 'PRP'), ('re', 'VBP'), ('hearing', 'VBG'), ('http', 'NN'), ('bit', 'NN'), ('ly', 'JJ'), ('6moswe', 'CD'), ('cnn', 'NN')]
# [('info', 'NN')]
# [('on', 'IN'), ('canada', 'JJ'), ('senagal', 'JJ'), ('usa', 'NN'), ('for', 'IN'), ('refugee', 'NN'), ('status', 'NN')]
# [('website', 'JJ'), ('url', 'JJ'), ('placeholder', 'NN')]
# [('navy', 'JJ'), ('diver', 'NN'), ('worked', 'VBD'), ('to', 'TO'), ('recover', 'VB'), ('body', 'NN'), ('a', 'DT'), ('a', 'DT'), ('central', 'JJ'), ('government', 'NN'), ('team', 'NN'), ('arrived', 'VBD'), ('in', 'IN'), ('the', 'DT'), ('region', 'NN'), ('to', 'TO'), ('examine', 'VB'), ('how', 'WRB'), ('to', 'TO'), ('drain', 'VB'), ('water', 'NN'), ('still', 'RB'), ('pooled', 'VBD'), ('18', 'CD'), ('metre', 'NN'), ('30', 'CD'), ('foot', 'NN'), ('deep', 'NN'), ('in', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('a', 'DT'), ('dozen', 'NN'), ('village', 'NN'), ('official', 'NN'), ('said', 'VBD'), ('monday', 'NN')]
# [('at', 'IN'), ('present', 'JJ'), ('one', 'CD'), ('il', 'NN'), ('76', 'CD'), ('plane', 'NN'), ('is', 'VBZ'), ('extinguishing', 'VBG'), ('fire', 'NN'), ('above', 'IN'), ('the', 'DT'), ('territory', 'NN'), ('of', 'IN'), ('the', 'DT'), ('kazakhstan', 'NN'), ('which', 'WDT'), ('border', 'NN'), ('with', 'IN'), ('the', 'DT'), ('russian', 'JJ'), ('federation', 'NN')]
# [('we', 'PRP'), ('think', 'VBP'), ('that', 'IN'), ('evaluation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('situation', 'NN'), ('in', 'IN'), ('the', 'DT'), ('idp', 'NN'), ('barrack', 'NN'), ('could', 'MD'), ('be', 'VB'), ('a', 'DT'), ('next', 'JJ'), ('step', 'NN'), ('to', 'TO'), ('implement', 'VB'), ('because', 'IN'), ('there', 'RB'), ('seems', 'VBZ'), ('to', 'TO'), ('be', 'VB'), ('reduced', 'VBN'), ('focus', 'NN'), ('on', 'IN'), ('this', 'DT'), ('problem', 'NN'), ('we', 'PRP'), ('already', 'RB'), ('visited', 'VBD'), ('one', 'CD'), ('idp', 'NN'), ('barrack', 'NN'), ('camp', 'NN'), ('and', 'CC'), ('found', 'VBD'), ('many', 'JJ'), ('case', 'NN'), ('of', 'IN'), ('scabies', 'NNS'), ('some', 'DT'), ('cutaneaous', 'JJ'), ('mycosis', 'NN'), ('and', 'CC'), ('skin', 'NN'), ('allergy', 'NN')]
# [('in', 'IN'), ('yen', 'JJ'), ('bai', 'NN'), ('province', 'NN'), ('there', 'EX'), ('were', 'VBD'), ('13', 'CD'), ('more', 'JJR'), ('house', 'NN'), ('submerged', 'VBN'), ('by', 'IN'), ('rising', 'VBG'), ('hong', 'RB'), ('river', 'NN'), ('s', 'JJ'), ('water', 'NN'), ('level', 'NN'), ('increasing', 'VBG'), ('the', 'DT'), ('number', 'NN'), ('of', 'IN'), ('house', 'NN'), ('flooded', 'VBN'), ('by', 'IN'), ('tropical', 'JJ'), ('storm', 'NN'), ('chanthu', 'NN'), ('s', 'NN'), ('gyre', 'NN'), ('to', 'TO'), ('145', 'CD')]
# [('note', 'NN'), ('it', 'PRP'), ('s', 'VBD'), ('already', 'RB'), ('translate', 'VB')]
# [('i', 'JJ'), ('m', 'NN'), ('at', 'IN'), ('gonaives', 'NNS'), ('my', 'PRP$'), ('native', 'JJ'), ('town', 'NN'), ('i', 'NN'), ('lost', 'VBD'), ('everything', 'NN'), ('after', 'IN'), ('the', 'DT'), ('earthquake', 'NN')]
# [('emergency', 'NN'), ('good', 'JJ'), ('portable', 'JJ'), ('toilet', 'NN'), ('shower', 'NN'), ('box', 'NN'), ('valued', 'VBN'), ('at', 'IN'), ('18', 'CD'), ('million', 'CD'), ('jpy', 'NN'), ('were', 'VBD'), ('locally', 'RB'), ('procured', 'VBN'), ('by', 'IN'), ('jica', 'NN')]
# [('the', 'DT'), ('displaced', 'JJ'), ('person', 'NN'), ('had', 'VBD'), ('been', 'VBN'), ('staying', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('series', 'NN'), ('of', 'IN'), ('small', 'JJ'), ('industrial', 'JJ'), ('building', 'NN'), ('in', 'IN'), ('the', 'DT'), ('town', 'NN'), ('of', 'IN'), ('surkhakhi', 'NN'), ('near', 'IN'), ('nazran', 'NN')]
# [('in', 'IN'), ('the', 'DT'), ('case', 'NN'), ('of', 'IN'), ('ashfall', 'NN'), ('particularly', 'RB'), ('with', 'IN'), ('fine', 'JJ'), ('particle', 'NN'), ('bronchial', 'JJ'), ('asthma', 'NN'), ('and', 'CC'), ('other', 'JJ'), ('chronic', 'JJ'), ('respiratory', 'NN'), ('condition', 'NN'), ('can', 'MD'), ('be', 'VB'), ('aggravated', 'VBN'), ('in', 'IN'), ('child', 'NN'), ('a', 'DT'), ('well', 'RB'), ('a', 'DT'), ('in', 'IN'), ('adult', 'NN'), ('the', 'DT'), ('un', 'JJ'), ('agency', 'NN'), ('say', 'VBP')]
# [('because', 'IN'), ('the', 'DT'), ('earthquake', 'NN'), ('cracked', 'VBD'), ('the', 'DT'), ('airport', 'NN'), ('s', 'VBD'), ('control', 'NN'), ('tower', 'NN'), ('traffic', 'NN'), ('ha', 'NN'), ('been', 'VBN'), ('directed', 'VBN'), ('from', 'IN'), ('a', 'DT'), ('temporary', 'JJ'), ('tower', 'NN'), ('in', 'IN'), ('an', 'DT'), ('elevated', 'JJ'), ('wooden', 'JJ'), ('shack', 'NN'), ('overlooking', 'VBG'), ('the', 'DT'), ('tarmac', 'NN')]
# []
#
# Index Error
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     350             This estimator
#     351         """
# --> 352         Xt, fit_params = self._fit(X, y, **fit_params)
#     353         with _print_elapsed_time('Pipeline',
#     354                                  self._log_message(len(self.steps) - 1)):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
#     315                 message_clsname='Pipeline',
#     316                 message=self._log_message(step_idx),
# --> 317                 **fit_params_steps[name])
#     318             # Replace the transformer of the step with the fitted
#     319             # transformer. This is necessary when loading the transformer
#
# ~\Anaconda3\lib\site-packages\joblib\memory.py in __call__(self, *args, **kwargs)
#     353
#     354     def __call__(self, *args, **kwargs):
# --> 355         return self.func(*args, **kwargs)
#     356
#     357     def call_and_shelve(self, *args, **kwargs):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit_transform(self, X, y, **fit_params)
#     910             sum of n_components (output dimension) over transformers.
#     911         """
# --> 912         results = self._parallel_func(X, y, fit_params, _fit_transform_one)
#     913         if not results:
#     914             # All transformers are None
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _parallel_func(self, X, y, fit_params, func)
#     940             message=self._log_message(name, idx, len(transformers)),
#     941             **fit_params) for idx, (name, transformer,
# --> 942                                     weight) in enumerate(transformers, 1))
#     943
#     944     def transform(self, X):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1005                 self._iterating = self._original_iterator is not None
#    1006
# -> 1007             while self.dispatch_one_batch(iterator):
#    1008                 pass
#    1009
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# ~\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     714     with _print_elapsed_time(message_clsname, message):
#     715         if hasattr(transformer, 'fit_transform'):
# --> 716             res = transformer.fit_transform(X, y, **fit_params)
#     717         else:
#     718             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
# --> 556             return self.fit(X, y, **fit_params).transform(X)
#     557
#     558
#
# <ipython-input-48-6a4a1e517be2> in transform(self, X)
#      59
#      60     def transform(self, X):
# ---> 61         X_tagged = pd.Series(X).apply(self.starting_verb)
#      62         return pd.DataFrame(X_tagged)
#      63
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-48-6a4a1e517be2> in starting_verb(self, text)
#      51             else:
#      52                 continue
# ---> 53             if first_tag in ['VB', 'VBP']:
#      54                 return True
#      55         return False
#
# UnboundLocalError: local variable 'first_tag' referenced before assignment

# %%
predictions = pipeline.predict(X_train)
eval_metrics(y_train, predictions, y.columns.values)

# %%
predictions = pipeline.predict(X_test)
eval_metrics(y_test, predictions, y.columns.values)

# %%
param_grid = {'features__text_pipeline__vect__ngram_range': ((1, 1), (1, 2)),
#               'features__text_pipeline__vect__max_df': (0.75, 1.0),
#               'clf__estimator__n_estimators': [100, 250, 500]
             }
model = build_model_pipeline()
scorer = make_scorer(gridsCV_scorer)
grid_model = GridSearchCV(model, param_grid=param_grid, scoring=scorer, verbose=20)
grid_model.fit(X_train, y_train)

# %%
best = grid_model.best_params_
best

# %%
predictions = grid_model.predict(X_test)
eval_m= eval_metrics(y_test, predictions, y.columns.values)

# %%
eval_m.describe()

# %%
joblib.dump(grid_model, 'DisasterResponse.pkl')

# %%
# # load the model from disk
# loaded_model = load('DisasterResponse.pkl')
# result = loaded_model.score(X_test, y_test)
# print(result)

# %%
grid_model
